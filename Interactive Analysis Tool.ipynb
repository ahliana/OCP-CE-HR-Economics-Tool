# %%
# Heat Reuse Economics Tool - Open Compute Project
print("Starting Heat Reuse Economics Tool...")
import sys, os
try:
    import google.colab
    IN_COLAB = True
    print("  Running in Google Colab")
except ImportError:
    IN_COLAB = False
    print("  Running locally")

if IN_COLAB:
    print("  Changing to /content directory...")
    os.chdir('/content')
    print("  Cloning repository...")
    # !git clone -q https://github.com/opencomputeproject/OCP-CE-HR-Economics-Tool.git 2>/dev/null || git -C OCP-CE-HR-Economics-Tool pull -q
    print("  Entering project directory...")
    os.chdir('/content/OCP-CE-HR-Economics-Tool')
    print("  Installing dependencies (this may take a moment)...")
    # !pip install -qq -r requirements.txt >/dev/null 2>&1
    print("  Enabling widget manager...")
    from google.colab import output
    output.enable_custom_widget_manager()
    print("  Setting up Python path...")
    sys.path.insert(0, '/content/OCP-CE-HR-Economics-Tool/python')
    print("  Loading interface...")
    from ui import display_interface
    display_interface()
    print("  Setup complete!")
else:
    sys.path.insert(0, f"{os.getcwd()}/python")
    import autostart
