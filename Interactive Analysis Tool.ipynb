# %%
import sys, os
sys.path.insert(0, f"{os.getcwd()}/python")
import autostart
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 sys.path.insert(0, f"{os.getcwd()}/python")
#       3 sys.path.append(os.path.abspath("."))
# ----> 4 from physics import autostart
#
# File c:\Files\Code\OCP-CE-HR-Economics-Tool/python\physics\__init__.py:27
#      25 from .heat_exchangers import *
#      26 from .materials import *
# ---> 27 from .units import *
#      29 __all__ = [
#      30     # Constants
#      31     'WATER_PROPERTIES', 'STANDARD_CONDITIONS', 'CONVERSION_FACTORS',
#    (...)     56     'watts_to_btu_per_hour', 'pressure_conversions'
#      57 ]
#
# AttributeError: module 'physics.units' has no attribute 'reynolds_number'
