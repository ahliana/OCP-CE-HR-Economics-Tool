# %%
# Heat Reuse Economics Tool
import sys, os
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # Setup for Google Colab
    os.chdir('/content')
    get_ipython().system('git clone --quiet https://github.com/opencomputeproject/OCP-CE-HR-Economics-Tool.git 2>/dev/null || true')
    os.chdir('/content/OCP-CE-HR-Economics-Tool')
    get_ipython().system('git pull --quiet')
    
    # Install dependencies BEFORE importing anything from the package
    print('Installing dependencies...')
    get_ipython().system('pip install -q -r requirements.txt')
    
    # Enable widget manager
    from google.colab import output
    output.enable_custom_widget_manager()
    
    # Now safe to import
    sys.path.insert(0, '/content/OCP-CE-HR-Economics-Tool/python')
    from ui.interface import display_logo, display_hxsimpledrawing, create_heat_reuse_interface
    from IPython.display import display
    
    display_logo()
    display_hxsimpledrawing()
    interface = create_heat_reuse_interface()
    if interface:
        display(interface['interface'])
else:
    sys.path.insert(0, f"{os.getcwd()}/python")
    import autostart
