# %%
# Heat Reuse Economics Tool - Open Compute Project
import sys, os
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    os.chdir('/content')
    get_ipython().system('git clone -q https://github.com/opencomputeproject/OCP-CE-HR-Economics-Tool.git 2>/dev/null || git -C OCP-CE-HR-Economics-Tool pull -q')
    os.chdir('/content/OCP-CE-HR-Economics-Tool')
    get_ipython().system('pip install -qq -r requirements.txt 2>/dev/null')
    from google.colab import output
    output.enable_custom_widget_manager()
    sys.path.insert(0, '/content/OCP-CE-HR-Economics-Tool/python')
    from ui.interface import display_logo, display_hxsimpledrawing, create_heat_reuse_interface
    from IPython.display import display
    display_logo()
    display_hxsimpledrawing()
    interface = create_heat_reuse_interface()
    if interface:
        display(interface["interface"])
else:
    sys.path.insert(0, f"{os.getcwd()}/python")
    import autostart
